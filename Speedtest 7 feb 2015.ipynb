# %%
import graphlab

# %%
sf = graphlab.SFrame('speedtest(feb_7_2015).csv')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to ttpro1995@gmail.com and will expire on February 02, 2017. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-23972 - Server binary: C:\Anaconda3\envs\dato-env\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\Thien\AppData\Local\Temp\graphlab_server_1455246084.log.0
# [INFO] GraphLab Server Version: 1.8.1
# PROGRESS: Finished parsing file C:\Users\Thien\IPython Notebook\ml-foundations\speedtest(feb_7_2015).csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.1172 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,float,long,long,float,str,float,long,float,str,str,float,long,str,long,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:61691/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target('ipynb')

# %%
sf.show()

# %%
sf['latency'].mean()
# Out:
# 0.0992748113144487

# %%
sf['latency'].max()
# Out:
# 6.42788043529
